# %%
import cv2
import matplotlib.pyplot as plt
path = "./out/conv1_1/"
img1 = cv2.imread(path + "600.png") # 0.001
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img1 = cv2.putText(img1, 'epoch:2000', (30,30), 1,2, (0,255,255), 3)

img2 = cv2.imread(path + "700.png") # 0.005
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
img2 = cv2.putText(img2, 'epoch:1900', (30,30), 1,2, (0,255,255), 3)

img3 = cv2.imread(path + "800.png") # 0.01
img3 = cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
img3 = cv2.putText(img3, 'epoch:1800', (30,30), 1,2, (0,255,255), 3)

img4 = cv2.imread(path + "900.png") # 0.01
img4 = cv2.cvtColor(img4,cv2.COLOR_BGR2RGB)
img4 = cv2.putText(img4, 'epoch:1700', (30,30), 1,2, (0,255,255), 3)

plt.figure(figsize=(10,10))
plt.subplot(141)
plt.imshow(img1)
plt.subplot(142)
plt.imshow(img2)
plt.subplot(143)
plt.imshow(img3)
plt.subplot(144)
plt.imshow(img4)

plt.show()
